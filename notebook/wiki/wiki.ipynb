]

# %%
visited_liks = {}
linkes_que = ['https://www.prothomalo.com//'] 
prothom_alo = 'https://www.prothomalo.com/'


visiting = True

def get_links(url):
    try : 
        while visiting == True: 
            url = linkes_que.pop(0)
            print(url)
            if visited_liks[url] == True:
                continue
           
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            find_link = soup.find_all('a')
            for link in find_link:
                if 'href' in link.attrs:
                    if link['href'].startswith('/'):
                        linkes_que.append(prothom_alo + link['href'])
                    else:
                        linkes_que.append(link['href'])

            visited_liks[url] = True


            
            print(len(linkes_que))
    except Exception as e:
        print(e)
        pass 

get_links(prothom_alo)


# response = requests.get(prothom_alo)
# soup = BeautifulSoup(response.text, 'html.parser')
# find_link = soup.find_all('a')

# for link in find_link:
#     if 'href' in link.attrs:
#         if link['href'].startswith('/'):
#             print(prothom_alo + link['href'])
#         else:
#             print(link['href'])
#         print(link.text)
# Out:
# https://www.prothomalo.com//
# 'https://www.prothomalo.com//'

# %%
response = requests.get(prothom_alo)
soup = BeautifulSoup(response.text, 'html.parser')
find_link = soup.find_all('a')

for link in find_link:
    if 'href' in link.attrs:
        if link['href'].startswith('/'):
            print(prothom_alo + link['href'])
        else:
            print(link['href'])
        print(link.text)
# Out:
# https://www.prothomalo.com//
#
# https://www.prothomalo.com//search
#
# https://www.prothomalo.com//api/auth/v1/oauth/authorize?client_id=811&response_type=code&redirect_uri=/api/auth/v1/oauth/token&callback_uri=/
# Login
# https://www.prothomalo.com/collection/latest
# সর্বশেষ
# https://www.prothomalo.com/politics
# রাজনীতি
# https://www.prothomalo.com/bangladesh
# বাংলাদেশ
# https://www.prothomalo.com/bangladesh/crime
# অপরাধ
# https://www.prothomalo.com/world
# বিশ্ব
# https://www.prothomalo.com/business
# বাণিজ্য
# https://www.prothomalo.com/opinion
# মতামত
# https://www.prothomalo.com/sports
# খেলা
# https://www.prothomalo.com/entertainment
# বিনোদন
# https://www.prothomalo.com/chakri
# চাকরি
# https://www.prothomalo.com/lifestyle
# জীবনযাপন
# https://www.prothomalo.com//search
# খুঁজুন
# https://epaper.prothomalo.com
# ই-পেপার
# https://en.prothomalo.com
# Eng
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from collections import deque

# Initialize the base URL and the queue for BFS
base_url = 'https://www.prothomalo.com'
visited = set()
queue = deque([base_url])

while queue:
    current_url = queue.popleft()
    if current_url in visited:
        continue

    visited.add(current_url)
    print(f"Visiting: {current_url}")

    try:
        response = requests.get(current_url)
        if response.status_code != 200:
            print(f"Failed to retrieve {current_url} - Status code: {response.status_code}")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        find_link = soup.find_all('a')

        for link in find_link:
            if 'href' in link.attrs:
                href = link['href']
                if href.startswith('/'):
                    full_url = urljoin(base_url, href)
                else:
                    full_url = href

                # Ensure the link is within the same domain
                if urlparse(full_url).netloc == urlparse(base_url).netloc:
                    if full_url not in visited:
                        queue.append(full_url)
                        print(f"Collected link: {full_url}")

    except requests.RequestException as e:
        print(f"Error visiting {current_url}: {e}")
# Out:
# Visiting: https://www.prothomalo.com
# Collected link: https://www.prothomalo.com/
# Collected link: https://www.prothomalo.com/search
# Collected link: https://www.prothomalo.com/api/auth/v1/oauth/authorize?client_id=811&response_type=code&redirect_uri=/api/auth/v1/oauth/token&callback_uri=/
# Collected link: https://www.prothomalo.com/collection/latest
# Collected link: https://www.prothomalo.com/politics
# Collected link: https://www.prothomalo.com/bangladesh
# Collected link: https://www.prothomalo.com/bangladesh/crime
# Collected link: https://www.prothomalo.com/world
# Collected link: https://www.prothomalo.com/business
# Collected link: https://www.prothomalo.com/opinion
# Collected link: https://www.prothomalo.com/sports
# Collected link: https://www.prothomalo.com/entertainment
# Collected link: https://www.prothomalo.com/chakri
# Collected link: https://www.prothomalo.com/lifestyle
# Collected link: https://www.prothomalo.com/search
# ...

# %%
#import all the likes in csv 

import pandas as pd 
visited= list(visited)
df = pd.DataFrame(visited, columns=['Links'])
df.to_csv('links.csv', index=False)

# %%
#remove all the link start containting 'https://www.prothomalo.com/api/auth/v1/oauth/authorize?client_id'ArithmeticError


df = pd.read_csv('links.csv')

df = df[~df['Links'].str.contains('https://www.prothomalo.com/api/auth/v1/oauth/authorize?client_id')]
df.to_csv('links.csv', index=False)

# %%
scrap_llm = "https://llm-automation.sslwireless.com/api/scrap-by-url?url="

data =[]

for link in visited:
    response = requests.get(scrap_llm + link)
    data.append(response.json()['content'])

# %%
data[:5]
# Out:
# ["গাইবান্ধার মৃত্যুদণ্ডপ্রাপ্ত সাবেক সংসদ সদস্য কর্নেল কাদের খান মারা গেছেন | প্রথম আলো  Loginসর্বশেষরাজনীতিবাংলাদেশঅপরাধবিশ্ববাণিজ্যমতামতখেলাবিনোদনচাকরিজীবনযাপনখুঁজুনই-পেপারEngLogin জেলাগাইবান্ধার মৃত্যুদণ্ডপ্রাপ্ত সাবেক সংসদ সদস্য কর্নেল কাদের খান মারা গেছেনপ্রতিনিধি গাইবান্ধাআপডেট: ১৯ জানুয়ারি ২০২৫, ১৬: ২৫ কর্নেল (অব.) আবদুল কাদের খানছবি: সংগৃহীতগাইবান্ধায় হত্যা মামলায় মৃত্যুদণ্ডাদেশপ্রাপ্ত জাতীয় পার্টির (জাপা) সাবেক সংসদ সদস্য কর্নেল (অব.) আবদুল কাদের খান (৭৮) মারা গেছেন। ঢাকার বঙ্গবন্ধু শেখ মুজিব মেডিকেল বিশ্ববিদ্যালয় (বিএসএমএমইউ) হাসপাতালে চিকিৎসাধীন অবস্থায় আজ রোববার ভোরে তাঁর মৃত্যু হয়।জাতীয় পার্টির নেতা আবদুল কাদের খান গাইবান্ধা-১ (সুন্দরগঞ্জ) আসনের সাবেক সংসদ সদস্য। ২০০৮ সালের নির্বাচনে মহাজোটের প্রার্থী হিসেবে জয়লাভ করেছিলেন তিনি। একই আসনের আওয়ামী লীগের সাবেক সংসদ সদস্য মঞ্জুরুল ইসলাম লিটন হত্যা মামলার প্রধান আসামি হিসেবে আদালত তাঁর মৃত্যুদণ্ড দেন। তিনি কেরানীগঞ্জে ঢাকা কেন্দ্রীয় কারাগারে বন্দী ছিলেন।ঢাকা কেন্দ্রীয় কারাগারের সিনিয়র জেল সুপার সুরাইয়া আক্তার বলেন, মৃতুদণ্ডপ
# ...

# %%
#save the data in csv 

df = pd.DataFrame(data, columns=['Data'])
df.to_csv('prothom_data.csv', index=False)

# %%
#drop all the row containing "{""message"":""\""params.redirect_uri\"" is required,\""params.response_type\"" is required""}"

for i in range(len(data)):
    if data[i] == '{"message":"\"params.redirect_uri\" is required,\"params.response_type\" is required"}':
        data.pop(i)

df = pd.DataFrame(data, columns=['Data'])
df.to_csv('prothom_data.csv', index=False)

# %%
#merge all the data in to one string 

data = pd.read_csv('prothom_data.csv')
string = '' 
for i in range(len(data)):
    string += data['Data'][i] 

len(string)
# Out:
# 4764635

# %%
import re 

#remove all english character 

string = re.sub(r'[a-zA-Z]', '', string)

# %%
string[:1000]
# Out:
# "গাইবান্ধার মৃত্যুদণ্ডপ্রাপ্ত সাবেক সংসদ সদস্য কর্নেল কাদের খান মারা গেছেন ''সর্বশেষরাজনীতিবাংলাদেশঅপরাধবিশ্ববাণিজ্যমতামতখেলাবিনোদনচাকরিজীবনযাপনখুঁজুনই-পেপার জেলাগাইবান্ধার মৃত্যুদণ্ডপ্রাপ্ত সাবেক সংসদ সদস্য কর্নেল কাদের খান মারা গেছেনপ্রতিনিধি গাইবান্ধাআপডেট: ১৯ জানুয়ারি ২০২৫, ১৬: ২৫ কর্নেল (অব.) আবদুল কাদের খানছবি: সংগৃহীতগাইবান্ধায় হত্যা মামলায় মৃত্যুদণ্ডাদেশপ্রাপ্ত জাতীয় পার্টির (জাপা) সাবেক সংসদ সদস্য কর্নেল (অব.) আবদুল কাদের খান (৭৮) মারা গেছেন। ঢাকার বঙ্গবন্ধু শেখ মুজিব মেডিকেল বিশ্ববিদ্যালয় (বিএসএমএমইউ) হাসপাতালে চিকিৎসাধীন অবস্থায় আজ রোববার ভোরে তাঁর মৃত্যু হয়।জাতীয় পার্টির নেতা আবদুল কাদের খান গাইবান্ধা-১ (সুন্দরগঞ্জ) আসনের সাবেক সংসদ সদস্য। ২০০৮ সালের নির্বাচনে মহাজোটের প্রার্থী হিসেবে জয়লাভ করেছিলেন তিনি। একই আসনের আওয়ামী লীগের সাবেক সংসদ সদস্য মঞ্জুরুল ইসলাম লিটন হত্যা মামলার প্রধান আসামি হিসেবে আদালত তাঁর মৃত্যুদণ্ড দেন। তিনি কেরানীগঞ্জে ঢাকা কেন্দ্রীয় কারাগারে বন্দী ছিলেন।ঢাকা কেন্দ্রীয় কারাগারের সিনিয়র জেল সুপার সুরাইয়া আক্তার বলেন, মৃতুদণ্ডপ্রাপ্ত কারাবন্দী কাদের খা
# ...

# %%
#svae this to a text file 
data_path= '/home/amzad/Desktop/bangla_GPT/dataset/prothom_alo.txt'
#read the data 

with open(data_path, "r", encoding="utf-8") as file:
    data = file.read()

# %%
data[-1000:]
# Out:
# 'নের বাসিন্দাদের জন্য। ভবনটির নির্মাণকাজ এখনো শেষ হয়নি। এর নির্মাণকাজ শেষ হতে আরও সাড়ে তিন বছর সময় লাগবে বলে দ্য ন্যাশনালের সংবাদে বলা হয়েছে।দুবাইয়ের আবাসন খাতে বিনিয়োগ প্রতিবছরই বাড়ছে। সংযুক্ত আরব আমিরাতের বিনিয়োগপ্রত্যাশী নীতির কারণে এই পরিস্থিতি সৃষ্টি হয়েছে। দেশটি আবাসন খাতে বিনিয়োগের জন্য অনেকটা দরজা খুলে রেখেছে। দুবাই শহরে বিনিয়োগ করার সক্ষমতা থাকলেই বাড়ি কেনা যায়। টাকা থাকলেই হলো, এর বাইরে আর কিছু খোঁজে না আরব আমিরাতের কর্তৃপক্ষ। সে কারণে দুবাই এখন সাধারণ বহুজাতিক নয়, বরং তা বিদেশিদের শহর হয়ে গেছে। তিন মিলিয়নের বেশি বা ৩০ লক্ষাধিক মানুষের দুবাই শহরে আমিরাতিরা সংখ্যালঘুতে পরিণত হয়েছে, তারা এখন মোট জনসংখ্যার মাত্র ৮ শতাংশ।ট্যাক্স অবজারভেটরির প্রতিবেদনে বলা হয়েছে, ২০২২ সালে দুবাই শহরে বিদেশিদের মালিকানাধীন আবাসনের মূল্য ছিল ১২১ বিলিয়ন বা ১২ হাজার ১০০ কোটি ডলার; ২০২০ সালে যা ছিল ৯৮ বিলিয়ন বা ৯ হাজার ৮০০ কোটি ডলার। অর্থমূল্যের বিবেচনায় দুবাই শহরের আবাসন খাতের ৪৩ শতাংশই এখন বিদেশিদের দখলে।প্রথম আলোর খবর পেতে গুগল নিউজ চ্যানেল ফলো করুনবিশ্ববাণিজ্য থেকে আরও পড়ুনফুটবলতারকাদুবাইইউরোপনেই
# ...

# %%
from bnlp import CleanText
clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=True,
   remove_email=False,
   remove_emoji=False,
   remove_number=True,
   remove_digits=False,
   remove_punct=False,
   replace_with_url="<URL>",
   replace_with_email="<EMAIL>",
   replace_with_number="<NUMBER>",
   replace_with_digit="<DIGIT>",
   replace_with_punct = "<PUNC>"
)

row = clean_text(data)

# %%
row[:1000]
# Out:
# "<_io.TextIOWrapper name='prothom_alo_cleaned.txt' mode='w' encoding='UTF-8'>"

# %%
#save this to a text file    
with open('prothom_alo_cleaned.txt', 'w') as f: 
    f.write(row)
